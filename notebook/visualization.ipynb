# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns 
import os

# %%
file_path = os.environ.get("MY_FILE_PATH")
if file_path:
    df_2 = pd.read_csv(file_path)
else:
    print("Environment variable MY_FILE_PATH is not set.")
# Out:
# Environment variable MY_FILE_PATH is not set.

# %%
df_2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# f:\mlops0\notebook\visualization.ipynb Cell 3 line 1
# ----> <a href='vscode-notebook-cell:/f%3A/mlops0/notebook/visualization.ipynb#W2sZmlsZQ%3D%3D?line=0'>1</a> df_2
#
# NameError: name 'df_2' is not defined

# %%
df.isnull().sum()/ 100
# Out:
# Unnamed: 0          0.00
# artist_name         0.15
# track_name          0.01
# track_id            0.00
# popularity          0.00
# year                0.00
# genre               0.00
# danceability        0.00
# energy              0.00
# key                 0.00
# loudness            0.00
# mode                0.00
# speechiness         0.00
# acousticness        0.00
# instrumentalness    0.00
# liveness            0.00
# valence             0.00
# tempo               0.00
# duration_ms         0.00
# time_signature      0.00
# dtype: float64

# %%
df_new = df[['artist_name','track_name','popularity','year' ,'genre','track_id']]

# %%
df_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1159764 entries, 0 to 1159763
# Data columns (total 6 columns):
#  #   Column       Non-Null Count    Dtype
# ---  ------       --------------    -----
#  0   artist_name  1159749 non-null  object
#  1   track_name   1159763 non-null  object
#  2   popularity   1159764 non-null  int64
#  3   year         1159764 non-null  int64
#  4   genre        1159764 non-null  object
#  5   track_id     1159764 non-null  object
# dtypes: int64(2), object(4)
# memory usage: 53.1+ MB

# %%
df_new['popularity'].max()
# Out:
# 100

# %%
df_new['popularity'].min()
# Out:
# 0

# %%
df_new['popularity'].describe()
# Out:
# count    1.159764e+06
# mean     1.838312e+01
# std      1.588554e+01
# min      0.000000e+00
# 25%      5.000000e+00
# 50%      1.500000e+01
# 75%      2.900000e+01
# max      1.000000e+02
# Name: popularity, dtype: float64

# %%
sns.histplot(df_new , x='popularity')
plt.show()

# %%
filtered_df = df_new[df_new['popularity'] > 20]

# %%
filtered_df
# Out:
#                   artist_name                                      track_name  \
# 0                  Jason Mraz                                 I Won't Give Up
# 1                  Jason Mraz                                93 Million Miles
# 2               Joshua Hyslop                                Do Not Let Me Go
# 3                Boyce Avenue                                        Fast Car
# 4                Andrew Belle                                Sky's Still Blue
# ...                       ...                                             ...
# 1159301          Mo' Horizons                   Around Ya feat. Fuel Fandango
# 1159312                GusGus                                  Be With Me Now
# 1159320                GusGus                                  Magnified Love
# 1159327              Röyksopp                                       Eple 2003
# 1159328  Thievery Corporation  Lebanese Blonde - Digitally Remastered Version
#
# ...

# %%
filtered_df.reset_index(drop=True, inplace=True)

# %%
sns.histplot(filtered_df , x='popularity')
plt.show()

# %%
filtered_df
# Out:
#                  artist_name                                      track_name  \
# 0                 Jason Mraz                                 I Won't Give Up
# 1                 Jason Mraz                                93 Million Miles
# 2              Joshua Hyslop                                Do Not Let Me Go
# 3               Boyce Avenue                                        Fast Car
# 4               Andrew Belle                                Sky's Still Blue
# ...                      ...                                             ...
# 454520          Mo' Horizons                   Around Ya feat. Fuel Fandango
# 454521                GusGus                                  Be With Me Now
# 454522                GusGus                                  Magnified Love
# 454523              Röyksopp                                       Eple 2003
# 454524  Thievery Corporation  Lebanese Blonde - Digitally Remastered Version
#
# ...

# %%
filtered_df['clean_track_name'] = filtered_df['track_name'].str.lower()
# Out:
# C:\Users\Win7\AppData\Local\Temp\ipykernel_1584\1063070138.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df['clean_track_name'] = filtered_df['track_name'].str.lower()

# %%
filtered_df
# Out:
#                  artist_name                                      track_name  \
# 0                 Jason Mraz                                 I Won't Give Up
# 1                 Jason Mraz                                93 Million Miles
# 2              Joshua Hyslop                                Do Not Let Me Go
# 3               Boyce Avenue                                        Fast Car
# 4               Andrew Belle                                Sky's Still Blue
# ...                      ...                                             ...
# 454520          Mo' Horizons                   Around Ya feat. Fuel Fandango
# 454521                GusGus                                  Be With Me Now
# 454522                GusGus                                  Magnified Love
# 454523              Röyksopp                                       Eple 2003
# 454524  Thievery Corporation  Lebanese Blonde - Digitally Remastered Version
#
# ...

# %%
filtered_df['clean_track_name'] = filtered_df['clean_track_name'].str.replace(r'\s+', '', regex=True)
# Out:
# C:\Users\Win7\AppData\Local\Temp\ipykernel_1584\402866614.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df['clean_track_name'] = filtered_df['clean_track_name'].str.replace(r'\s+', '', regex=True)

# %%
filtered_df
# Out:
#                  artist_name                                      track_name  \
# 0                 Jason Mraz                                 I Won't Give Up
# 1                 Jason Mraz                                93 Million Miles
# 2              Joshua Hyslop                                Do Not Let Me Go
# 3               Boyce Avenue                                        Fast Car
# 4               Andrew Belle                                Sky's Still Blue
# ...                      ...                                             ...
# 454520          Mo' Horizons                   Around Ya feat. Fuel Fandango
# 454521                GusGus                                  Be With Me Now
# 454522                GusGus                                  Magnified Love
# 454523              Röyksopp                                       Eple 2003
# 454524  Thievery Corporation  Lebanese Blonde - Digitally Remastered Version
#
# ...

# %%
filtered_df.head(5)
# Out:
#      artist_name        track_name  popularity  year     genre  \
# 0     Jason Mraz   I Won't Give Up          68  2012  acoustic
# 1     Jason Mraz  93 Million Miles          50  2012  acoustic
# 2  Joshua Hyslop  Do Not Let Me Go          57  2012  acoustic
# 3   Boyce Avenue          Fast Car          58  2012  acoustic
# 4   Andrew Belle  Sky's Still Blue          54  2012  acoustic
#
#                  track_id clean_track_name
# 0  53QF56cjZA9RTuuMZDrSA6     iwon'tgiveup
# 1  1s8tP3jP4GZcyHDsjvw218   93millionmiles
# 2  7BRCa8MPiyuvr2VU3O9W0F     donotletmego
# 3  63wsZUhUZLlh1OsyrZq7sz          fastcar
# 4  6nXIYClvJAfi6ujLiKqEq8   sky'sstillblue

# %%
def create_url(track_id):
    base_url = 'https://open.spotify.com/track/'
    return base_url +  track_id  

# Apply the function to the 'clean_track_name' and 'track_id' columns to create 'info_url'
filtered_df['info_url'] = filtered_df.apply(lambda row: create_url(row['track_id']), axis=1)
# Out:
# C:\Users\Win7\AppData\Local\Temp\ipykernel_1584\2339734024.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df['info_url'] = filtered_df.apply(lambda row: create_url(row['track_id']), axis=1)

# %%
filtered_df
# Out:
#                  artist_name                                      track_name  \
# 0                 Jason Mraz                                 I Won't Give Up
# 1                 Jason Mraz                                93 Million Miles
# 2              Joshua Hyslop                                Do Not Let Me Go
# 3               Boyce Avenue                                        Fast Car
# 4               Andrew Belle                                Sky's Still Blue
# ...                      ...                                             ...
# 454520          Mo' Horizons                   Around Ya feat. Fuel Fandango
# 454521                GusGus                                  Be With Me Now
# 454522                GusGus                                  Magnified Love
# 454523              Röyksopp                                       Eple 2003
# 454524  Thievery Corporation  Lebanese Blonde - Digitally Remastered Version
#
# ...

# %%
filtered_df.drop(columns=['clean_track_name'],inplace=True)
# Out:
# C:\Users\Win7\AppData\Local\Temp\ipykernel_1584\3435297572.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df.drop(columns=['clean_track_name'],inplace=True)

# %%
filtered_df['info_url'][0]
# Out:
# 'https://open.spotify.com/track/53QF56cjZA9RTuuMZDrSA6'

# %% [markdown]
# # Visualizing some plots

# %%
plt.figure(figsize=(15,10))
sns.lineplot(filtered_df , x='year',y='popularity')
plt.show()

# %%
artist_popularity = filtered_df.groupby('artist_name')['popularity'].sum().reset_index()

# Sort the DataFrame in descending order by 'popularity' and take the top ten
top_ten_artists = artist_popularity.sort_values(by='popularity', ascending=False).head(10)

top_ten_artists
# Out:
#                  artist_name  popularity
# 16486            Hans Zimmer       22961
# 32402                 Pritam       20926
# 15493              Glee Cast       19555
# 19883  Johann Sebastian Bach       18527
# 9                $uicideboy$       16862
# 39248           Taylor Swift       16504
# 11404                  Drake       16080
# 34876            SICK LEGEND       15389
# 26733            Max Richter       14958
# 2866        Armin van Buuren       14419

# %%
# Create a bar plot
plt.figure(figsize=(10, 6))
plt.barh(top_ten_artists['artist_name'], top_ten_artists['popularity'])
plt.xlabel('Popularity')
plt.ylabel('Artist Name')
plt.title('Top Ten Artists by Popularity')
plt.gca().invert_yaxis()  # Invert y-axis to show the most popular artist at the top
plt.show()

# %%
plt.figure(figsize=(8, 8))
plt.pie(top_ten_artists['popularity'], labels=top_ten_artists['artist_name'], autopct='%1.1f%%', startangle=90)
plt.title('Top Ten Artists by Popularity')
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.show()

# %%
artist_popularity = filtered_df.groupby('artist_name').agg({'popularity': 'sum'}).reset_index()

# Sort artists by total popularity in descending order and select the top ten
top_ten_artists = artist_popularity.sort_values(by='popularity', ascending=False).head(20)

# Initialize a list to store dictionaries with artist data
artist_data_list = []

# Iterate through the top ten artists and find their most popular track and year
for artist_name in top_ten_artists['artist_name']:
    artist_data = filtered_df[filtered_df['artist_name'] == artist_name]
    most_popular_track = artist_data.loc[artist_data['popularity'].idxmax()]['track_name']
    year = artist_data.loc[artist_data['popularity'].idxmax()]['year']
    artist_data_list.append({'artist_name': artist_name, 'most_popular_track': most_popular_track, 'year': year})

# Create a DataFrame from the list of dictionaries
most_popular_tracks = pd.DataFrame(artist_data_list)

most_popular_tracks
# Out:
#                 artist_name  \
# 0               Hans Zimmer
# 1                    Pritam
# 2                 Glee Cast
# 3     Johann Sebastian Bach
# 4               $uicideboy$
# 5              Taylor Swift
# 6                     Drake
# 7               SICK LEGEND
# 8               Max Richter
# 9          Armin van Buuren
# 10       Sleep Fruits Music
# 11                      BTS
# 12              Piano Peace
# 13              The Beatles
# 14                   Future
# 15             Boyce Avenue
# 16          Little Symphony
# 17                   Eminem
# 18  Wolfgang Amadeus Mozart
# 19            Ramin Djawadi
#
#                                    most_popular_track  year
# 0                                     Cornfield Chase  2014
# 1                        Kesariya (From "Brahmastra")  2022
# 2                       Footloose (Glee Cast Version)  2014
# 3           Suite No. 3 in D Major, BWV 1068: II. Air  2020
# ...

# %%
plt.figure(figsize=(15, 6))
most_popular_tracks['most_popular_track_truncated'] = most_popular_tracks['most_popular_track'].str[:30]  
bars = plt.barh(most_popular_tracks['most_popular_track_truncated'], most_popular_tracks['artist_name'])
plt.xlabel('Popularity')
plt.ylabel('Artist Name')
plt.xticks(rotation='vertical')
plt.title('Top 30 Artists by Popularity')
plt.gca().invert_yaxis()
plt.show()

# %%
plt.figure(figsize=(15, 6))
sns.lineplot(most_popular_tracks,x='year',y='artist_name')
plt.xticks(rotation='vertical')
plt.gca().invert_yaxis()
plt.show()

# %%
filtered_df
# Out:
#                  artist_name                                      track_name  \
# 0                 Jason Mraz                                 I Won't Give Up
# 1                 Jason Mraz                                93 Million Miles
# 2              Joshua Hyslop                                Do Not Let Me Go
# 3               Boyce Avenue                                        Fast Car
# 4               Andrew Belle                                Sky's Still Blue
# ...                      ...                                             ...
# 454520          Mo' Horizons                   Around Ya feat. Fuel Fandango
# 454521                GusGus                                  Be With Me Now
# 454522                GusGus                                  Magnified Love
# 454523              Röyksopp                                       Eple 2003
# 454524  Thievery Corporation  Lebanese Blonde - Digitally Remastered Version
#
# ...

# %%
genre_popularity = filtered_df.groupby('genre')['popularity'].sum().reset_index()

# Sort the DataFrame in descending order by 'popularity' and take the top ten
top_ten_genre = genre_popularity.sort_values(by='popularity', ascending=False).head(10)

top_ten_genre
# Out:
#        genre  popularity
# 2   alt-rock      805444
# 14     dance      728547
# 42   hip-hop      726007
# 13   country      533279
# 27      folk      509989
# 48     k-pop      472225
# 47      jazz      435811
# 9      chill      429484
# 29    french      410983
# 26       emo      401118

# %%
# Create a bar plot
plt.figure(figsize=(15, 6))
plt.barh(top_ten_genre['genre'], top_ten_genre['popularity'])
plt.xlabel('Popularity')
plt.ylabel('top_ten_genre')
plt.title('Top ten genre by Popularity')
plt.gca().invert_yaxis()  
plt.show()

# %%
filtered_df
# Out:
#                  artist_name                                      track_name  \
# 0                 Jason Mraz                                 I Won't Give Up
# 1                 Jason Mraz                                93 Million Miles
# 2              Joshua Hyslop                                Do Not Let Me Go
# 3               Boyce Avenue                                        Fast Car
# 4               Andrew Belle                                Sky's Still Blue
# ...                      ...                                             ...
# 454520          Mo' Horizons                   Around Ya feat. Fuel Fandango
# 454521                GusGus                                  Be With Me Now
# 454522                GusGus                                  Magnified Love
# 454523              Röyksopp                                       Eple 2003
# 454524  Thievery Corporation  Lebanese Blonde - Digitally Remastered Version
#
# ...

# %% [markdown]
# # Cleaning the data

# %%
filtered_df['track_name'] = filtered_df['track_name'].str.lower()
# Out:
# C:\Users\Win7\AppData\Local\Temp\ipykernel_1584\909556054.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df['track_name'] = filtered_df['track_name'].str.lower()

# %%
filtered_df['artist_name'] = filtered_df['artist_name'].str.lower()
# Out:
# C:\Users\Win7\AppData\Local\Temp\ipykernel_1584\3639067459.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df['artist_name'] = filtered_df['artist_name'].str.lower()

# %%
filtered_df
# Out:
#                  artist_name                                      track_name  \
# 0                 jason mraz                                 i won't give up
# 1                 jason mraz                                93 million miles
# 2              joshua hyslop                                do not let me go
# 3               boyce avenue                                        fast car
# 4               andrew belle                                sky's still blue
# ...                      ...                                             ...
# 454520          mo' horizons                   around ya feat. fuel fandango
# 454521                gusgus                                  be with me now
# 454522                gusgus                                  magnified love
# 454523              röyksopp                                       eple 2003
# 454524  thievery corporation  lebanese blonde - digitally remastered version
#
# ...

# %%
filtered_df['artist_name'] = filtered_df['artist_name'].str.strip()
filtered_df['track_name'] = filtered_df['track_name'].str.strip()
# Out:
# C:\Users\Win7\AppData\Local\Temp\ipykernel_1584\2700955592.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df['artist_name'] = filtered_df['artist_name'].str.strip()
# C:\Users\Win7\AppData\Local\Temp\ipykernel_1584\2700955592.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df['track_name'] = filtered_df['track_name'].str.strip()

# %%
filtered_df
# Out:
#                  artist_name                                      track_name  \
# 0                 jason mraz                                 i won't give up
# 1                 jason mraz                                93 million miles
# 2              joshua hyslop                                do not let me go
# 3               boyce avenue                                        fast car
# 4               andrew belle                                sky's still blue
# ...                      ...                                             ...
# 454520          mo' horizons                   around ya feat. fuel fandango
# 454521                gusgus                                  be with me now
# 454522                gusgus                                  magnified love
# 454523              röyksopp                                       eple 2003
# 454524  thievery corporation  lebanese blonde - digitally remastered version
#
# ...

# %%
filtered_df['info_url'][10]
# Out:
# 'https://open.spotify.com/track/1RjEDlhTp2iJXWPdLpa8OM'

# %%
filtered_df
# Out:
#                  artist_name                                      track_name  \
# 0                 jason mraz                                 i won't give up
# 1                 jason mraz                                93 million miles
# 2              joshua hyslop                                do not let me go
# 3               boyce avenue                                        fast car
# 4               andrew belle                                sky's still blue
# ...                      ...                                             ...
# 454520          mo' horizons                   around ya feat. fuel fandango
# 454521                gusgus                                  be with me now
# 454522                gusgus                                  magnified love
# 454523              röyksopp                                       eple 2003
# 454524  thievery corporation  lebanese blonde - digitally remastered version
#
# ...

# %%
filtered_df.columns
# Out:
# Index(['artist_name', 'track_name', 'popularity', 'year', 'genre', 'track_id',
#        'info_url'],
#       dtype='object')

# %%
# Calculate track popularity scores (e.g., sum of popularity for each track)
track_popularity = filtered_df.groupby('info_url')['popularity'].sum().reset_index()

# Sort tracks by popularity in descending order
sorted_tracks = track_popularity.sort_values(by='popularity', ascending=False)

# Function to get popular track recommendations
def get_popular_track_recommendations(n=5):
    # Get the top N popular tracks as recommendations
    recommendations = sorted_tracks['info_url'][:n]
    return recommendations

# Example: Get popular track recommendations
recommendations = get_popular_track_recommendations(n=5)
print("Popular Track Recommendations:")
print(recommendations)
# Out:
# Popular Track Recommendations:
# 56976     https://open.spotify.com/track/0yLdNVWF3Srea0u...
# 280829    https://open.spotify.com/track/4nrPB8O7Y7wsOCJ...
# 443311    https://open.spotify.com/track/7oDd86yk8itslrA...
# 84133     https://open.spotify.com/track/1Qrg8KqiBpW07V7...
# 347342    https://open.spotify.com/track/5ww2BF9slyYgNOk...
# Name: info_url, dtype: object

# %%
filtered_df['info_url'][131747]
# Out:
# 'https://open.spotify.com/track/35vWwu4R3RPImyDGzBXWzB'

# %%
unique_genre = filtered_df['genre'].nunique

# %%
unique_artist = filtered_df['artist_name'].nunique

# %%
user_favorite_artist = input(f"what are your favourite artist {unique_artist}")
user_favorite_artist
# Out:
# 'drake '

# %%
artist_filtered_songs = filtered_df[filtered_df['artist_name'] == user_favorite_artist]
artist_filtered_songs
# Out:
# Empty DataFrame
# Columns: [artist_name, track_name, popularity, year, genre, track_id, info_url]
# Index: []

# %%
# Filter songs based on user's favorite artist
artist_filtered_songs = filtered_df[filtered_df['artist_name'] == user_favorite_artist]

# Combine both filters to get songs that match both criteria
user_filtered_songs = pd.concat([ artist_filtered_songs])

# Sort the filtered songs by popularity or other relevant factors
sorted_user_filtered_songs = user_filtered_songs.sort_values(by='popularity', ascending=False)

# Get the top N recommended songs with artist names
n = 5
recommended_songs = sorted_user_filtered_songs[['artist_name', 'track_name']][:n]

# Display the recommended songs with artist names
print("Recommended Songs:")
for idx, row in recommended_songs.iterrows():
    print(f"{row['artist_name']} - {row['track_name']}")
# Out:
# Recommended Songs:

# %%
import logging

# %%
class RecommendationEngine:
    """
    A class to recommend songs by a specific artist from a DataFrame.
    """

    def __init__(self, df):
        """
        Initialize the RecommendationEngine with a DataFrame containing song data.
        
        :param df: DataFrame with columns 'artist_name', 'genre', 'track_name', and 'info_url'.
        """
        self.df = df
        self.logger = self.setup_logger()

    def setup_logger(self):
        """
        Set up a logger for the class.
        """
        logger = logging.getLogger(__name__)
        logger.setLevel(logging.INFO)
        formatter = logging.Formatter('%(asctime)s - %(levelname)s - %(message)s')
        ch = logging.StreamHandler()
        ch.setFormatter(formatter)
        logger.addHandler(ch)
        return logger

    def recommend_songs_by_artist(self, artist_name, n=5):
        """
        Recommend songs by the specified artist.

        :param artist_name: The name of the artist.
        :param n: Number of songs to recommend (default is 5).
        :return: A DataFrame with the top recommended songs.
        """
        try:
            user_filtered_songs = self.df[self.df['artist_name'] == artist_name]
            
             

            sorted_user_filtered_songs = user_filtered_songs.sort_values(by='popularity', ascending=False)

            # Get the top N recommended songs with artist names, genre, track_name, and info_url
            recommended_songs_love = sorted_user_filtered_songs[['artist_name', 'genre', 'track_name', 'info_url','popularity']][:n]

            self.logger.info("Recommended Songs:")
            return recommended_songs_love
        except (KeyError, ValueError) as e:
            self.logger.error(f"An error occurred while recommending the data: {str(e)}")
            return pd.DataFrame()

# %%
def input_cleaning(user_input: str):
    if user_input is not None:
       
        lower_input = user_input.lower()
        cleaned_input = lower_input.strip()

        return cleaned_input
    else:
        return None

# %%
filtered_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 454525 entries, 0 to 454524
# Data columns (total 7 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   artist_name  454517 non-null  object
#  1   track_name   454525 non-null  object
#  2   popularity   454525 non-null  int64
#  3   year         454525 non-null  int64
#  4   genre        454525 non-null  object
#  5   track_id     454525 non-null  object
#  6   info_url     454525 non-null  object
# dtypes: int64(2), object(5)
# memory usage: 24.3+ MB

# %%
filtered_df['artist_name'] == 'Lana del ray'
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 454520    False
# 454521    False
# 454522    False
# 454523    False
# 454524    False
# Name: artist_name, Length: 454525, dtype: bool

# %%
recommennd = RecommendationEngine(filtered_df)
user_input_llaa = input("What's your favorite artist: ")
clean_input = input_cleaning(user_input_llaa)
recommended_songs = recommennd.recommend_songs_by_artist(clean_input)

if recommended_songs.empty:
    print("No recommended songs found for the specified artist.")
else:
    for index, song in recommended_songs.iterrows():
        print(f"Artist: {song['artist_name']}")
        print(f"Genre: {song['genre']}")
        print(f"Popularity: {song['popularity']}")
        print(f"Track: {song['track_name']}")
        print(f"URL: {song['info_url']}")

        print("\n")
# Out:
# 2023-10-09 17:54:35,004 - INFO - Recommended Songs:
# Artist: drake
# Genre: hip-hop
# Popularity: 90
# Track: rich flex
# URL: https://open.spotify.com/track/1bDbXMyjaUIooNwFE9wn0N
#
#
# Artist: drake
# Genre: hip-hop
# Popularity: 86
# Track: jimmy cooks (feat. 21 savage)
# URL: https://open.spotify.com/track/3F5CgOj3wFlRv51JsHbxhe
#
#
# Artist: drake
# Genre: hip-hop
# Popularity: 84
# Track: one dance
# URL: https://open.spotify.com/track/1zi7xx7UVEFkmKfv06H8x0
#
#
# Artist: drake
# Genre: hip-hop
# Popularity: 83
# Track: god's plan
# URL: https://open.spotify.com/track/6DCZcSspjsKoFjzjrWoCdn
#
#
# Artist: drake
# Genre: hip-hop
# Popularity: 82
# Track: spin bout u
# URL: https://open.spotify.com/track/2ZL7WZcjuYKi1KUDtp4kCC

# %%
filtered_df['artist_name'] == 'drake '
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 454520    False
# 454521    False
# 454522    False
# 454523    False
# 454524    False
# Name: artist_name, Length: 454525, dtype: bool

# %%
class RecommendationEngine_forsongs:
    """
    A class to recommend songs by a specific track from a DataFrame.
    """

    def __init__(self, df):
        """
        Initialize the RecommendationEngine with a DataFrame containing song data.
        
        :param df: DataFrame with columns 'artist_name', 'genre', 'track_name', and 'info_url'.
        """
        self.df = df
        self.logger = self.setup_logger()

    def setup_logger(self):
        """
        Set up a logger for the class.
        """
        logger = logging.getLogger(__name__)
        logger.setLevel(logging.INFO)
        formatter = logging.Formatter('%(asctime)s - %(levelname)s - %(message)s')
        ch = logging.StreamHandler()
        ch.setFormatter(formatter)
        logger.addHandler(ch)
        return logger

    def recommend_songs_by_songs(self, track_name, n=5):
        """
        Recommend songs by the specified artist.

        :param artist_name: The name of the artist.
        :param n: Number of songs to recommend (default is 5).
        :return: A DataFrame with the top recommended songs.
        """
        try:
            user_filtered_songs = self.df[self.df['track_name'] == track_name]
            
             

            sorted_user_filtered_songs = user_filtered_songs.sort_values(by='popularity', ascending=False)

            # Get the top N recommended songs with artist names, genre, track_name, and info_url
            recommended_songs_love = sorted_user_filtered_songs[['artist_name', 'genre', 'track_name', 'info_url','popularity']][:n]

            self.logger.info("Recommended Songs:")
            return recommended_songs_love
        except (KeyError, ValueError) as e:
            self.logger.error(f"An error occurred while recommending the data: {str(e)}")
            return pd.DataFrame()

# %%
recommennd_1 = RecommendationEngine_forsongs(filtered_df)
user_input_songs = input("give the song name : ")
clean_input_for_songs = input_cleaning(user_input_songs)
recommended_songs_songs = recommennd_1.recommend_songs_by_songs(clean_input_for_songs)

if recommended_songs_songs.empty:
    print("No recommended songs found for the specified artist.")
else:
    for index, songs1 in recommended_songs_songs.iterrows():
        print(f"Artist: {songs1['artist_name']}")
        print(f"Genre: {songs1['genre']}")
        print(f"Popularity: {songs1['popularity']}")
        print(f"Track: {songs1['track_name']}")
        print(f"URL: {songs1['info_url']}")

        print("\n")
# Out:
# 2023-10-09 17:54:38,674 - INFO - Recommended Songs:
# 2023-10-09 17:54:38,674 - INFO - Recommended Songs:
# Artist: drake
# Genre: hip-hop
# Popularity: 90
# Track: rich flex
# URL: https://open.spotify.com/track/1bDbXMyjaUIooNwFE9wn0N

# %%
class RecommendBasedOnArtistSongs:
    """
    A class to recommend songs by a specific artist and song name from a DataFrame.
    """

    def __init__(self, df):
        """
        Initialize the RecommendationEngine with a DataFrame containing song data.

        :param df: DataFrame with columns 'artist_name', 'genre', 'track_name', 'info_url', and 'popularity'.
        """
        self.df = df
        self.logger = self.setup_logger()

    def setup_logger(self):
        """
        Set up a logger for the class.
        """
        logger = logging.getLogger(__name__)
        logger.setLevel(logging.INFO)
        formatter = logging.Formatter('%(asctime)s - %(levelname)s - %(message)s')
        ch = logging.StreamHandler()
        ch.setFormatter(formatter)
        logger.addHandler(ch)
        return logger

    def recommends_songs_artist(self, artist, track, n=5):
        """
        Recommend songs by the specified artist and song.

        :param artist: The name of the artist.
        :param track: The name of the song.
        :param n: Number of songs to recommend (default is 5).
        :return: Two DataFrames with the top recommended songs, one for the artist and one for the song,
                 along with the user-inputted artist and track.
        """
        try:
            # Filter songs by the specified track name
            user_filtered_songs = self.df[self.df['track_name'] == track]
            
            # Filter songs by the specified artist name
            user_filtered_artist = self.df[self.df['artist_name'] == artist]

            # Sort the filtered DataFrames by popularity in descending order
            sorted_user_filtered_songs = user_filtered_songs.sort_values(by='popularity', ascending=False)
            sorted_user_filtered_artist = user_filtered_artist.sort_values(by='popularity', ascending=False)

            # Get the top N recommended songs with artist names, genre, track_name, and info_url
            recommended_songs_by_track = sorted_user_filtered_songs[['artist_name', 'genre', 'track_name', 'info_url', 'popularity']][:n]
            recommended_songs_by_artist = sorted_user_filtered_artist[['artist_name', 'genre', 'track_name', 'info_url', 'popularity']][:n]

            self.logger.info("Recommended Songs:")
            return recommended_songs_by_track, recommended_songs_by_artist, artist, track
        except (KeyError, ValueError) as e:
            self.logger.error(f"An error occurred while recommending the data: {str(e)}")
            return pd.DataFrame(), pd.DataFrame(), artist, track

# %%
recommendation_engine = RecommendBasedOnArtistSongs(filtered_df)
recommended_songs_by_songs, recommended_songs_by_artist = recommendation_engine.recommends_songs_artist("world cup", "ishowspeed")
# Out:
# 2023-10-09 17:54:38,771 - INFO - Recommended Songs:
# 2023-10-09 17:54:38,771 - INFO - Recommended Songs:
# 2023-10-09 17:54:38,771 - INFO - Recommended Songs:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# f:\mlops2\notebook\visualization.ipynb Cell 65 line 2
#       <a href='vscode-notebook-cell:/f%3A/mlops2/notebook/visualization.ipynb#Y121sZmlsZQ%3D%3D?line=0'>1</a> recommendation_engine = RecommendBasedOnArtistSongs(filtered_df)
# ----> <a href='vscode-notebook-cell:/f%3A/mlops2/notebook/visualization.ipynb#Y121sZmlsZQ%3D%3D?line=1'>2</a> recommended_songs_by_songs, recommended_songs_by_artist = recommendation_engine.recommends_songs_artist("world cup", "ishowspeed")
#
# ValueError: too many values to unpack (expected 2)

# %%
recommended_songs_by_songs
# Out:
# Empty DataFrame
# Columns: [artist_name, genre, track_name, info_url, popularity]
# Index: []

# %%
recommennd_1_2 = RecommendBasedOnArtistSongs(filtered_df)

# Take user input for the song name and artist name
user_input_songs = input("Enter the song name: ")
user_input_artist_name = input("Enter the artist name: ")

# Clean the user inputs
clean_input_for_songs = input_cleaning(user_input_songs.strip())
print(clean_input_for_songs)
clean_input_for_artist = input_cleaning(user_input_artist_name)

# Get song recommendations
recommended_songs_by_track, recommended_songs_by_artist = recommennd_1_2.recommends_songs_artist(clean_input_for_songs, clean_input_for_artist)

if recommended_songs_by_track.empty and recommended_songs_by_artist.empty:
    print("No recommended songs found for the specified artist or song.")
else:
    if not recommended_songs_by_track.empty:
        print("Recommended Songs by Track:")
        for index, song in recommended_songs_by_track.iterrows():
            print(f"Artist: {song['artist_name']}")
            print(f"Genre: {song['genre']}")
            print(f"Popularity: {song['popularity']}")
            print(f"Track: {song['track_name']}")
            print(f"URL: {song['info_url']}")
            print("\n")

    if not recommended_songs_by_artist.empty:
        print("Recommended Songs by Artist:")
        for index, song in recommended_songs_by_artist.iterrows():
            print(f"Artist: {song['track_name']}")  # Corrected artist and track names here
            print(f"Genre: {song['genre']}")
            print(f"Popularity: {song['popularity']}")
            print(f"Track: {song['artist_name']}")  # Corrected artist and track names here
            print(f"URL: {song['info_url']}")
            print("\n")
# Out:
# 2023-10-08 12:15:37,181 - INFO - Recommended Songs:
# 2023-10-08 12:15:37,181 - INFO - Recommended Songs:
# 2023-10-08 12:15:37,181 - INFO - Recommended Songs:
# 2023-10-08 12:15:37,181 - INFO - Recommended Songs:
# 2023-10-08 12:15:37,181 - INFO - Recommended Songs:
# 2023-10-08 12:15:37,181 - INFO - Recommended Songs:
# 2023-10-08 12:15:37,181 - INFO - Recommended Songs:
# 2023-10-08 12:15:37,181 - INFO - Recommended Songs:
# 2023-10-08 12:15:37,181 - INFO - Recommended Songs:
# 2023-10-08 12:15:37,181 - INFO - Recommended Songs:
# 2023-10-08 12:15:37,181 - INFO - Recommended Songs:
# 2023-10-08 12:15:37,181 - INFO - Recommended Songs:
# 2023-10-08 12:15:37,181 - INFO - Recommended Songs:
# 2023-10-08 12:15:37,181 - INFO - Recommended Songs:
# 2023-10-08 12:15:37,181 - INFO - Recommended Songs:
# 2023-10-08 12:15:37,181 - INFO - Recommended Songs:
# 2023-10-08 12:15:37,181 - INFO - Recommended Songs:
# 2023-10-08 12:15:37,181 - INFO - Recommended Songs:
# ...

# %%
class SongRecommendation_lovely:
    def __init__(self, df):
        """
        Initialize the SongRecommendation class with a DataFrame containing song data.

        :param df: DataFrame with columns 'artist_name', 'genre', 'track_name', 'info_url', and 'popularity'.
        """
        self.df = df

    def recommend_similar_songs(self, artist, song, n=5):
        """
        Recommend songs that are similar to the given artist and song.

        :param artist: The name of the artist.
        :param song: The name of the song.
        :param n: Number of songs to recommend (default is 5).
        :return: A DataFrame with the top recommended songs.
        """
        try:
            # Filter songs by the same artist and a different song (exclude the given song)
            similar_songs = self.df[(self.df['artist_name'] == artist) & (self.df['track_name'] != song)]
            
            # Sort the filtered DataFrame by popularity in descending order
            sorted_similar_songs = similar_songs.sort_values(by='popularity', ascending=False)

            # Get the top N recommended similar songs with artist names, genre, track_name, and info_url
            recommended_songs = sorted_similar_songs[['artist_name', 'genre', 'track_name', 'info_url', 'popularity']][:n]

            return recommended_songs
        except (KeyError, ValueError) as e:
            print(f"An error occurred while recommending similar songs: {str(e)}")
            return pd.DataFrame()
        

recommendation_engine_wow = SongRecommendation_lovely(filtered_df)

# Take user input for the song name and artist name
user_input_songs = input("Enter the song name: ")
user_input_artist_name = input("Enter the artist name: ")

# Clean the user inputs
clean_input_for_songs = input_cleaning(user_input_songs)

clean_input_for_artist = input_cleaning(user_input_artist_name)

recommended_similar_songs_holy = recommendation_engine_wow.recommend_similar_songs(clean_input_for_artist, clean_input_for_songs)

if recommended_similar_songs_holy.empty:
    print("No recommended songs found for the specified artist or song.")
else:
    if not recommended_similar_songs_holy.empty:
        print("Recommended Songs by Track:")
        for index, song in recommended_similar_songs_holy.iterrows():
            print(f"Artist: {song['artist_name']}")
            print(f"Genre: {song['genre']}")
            print(f"Popularity: {song['popularity']}")
            print(f"Track: {song['track_name']}")
            print(f"URL: {song['info_url']}")
            print("\n")
# Out:
# Recommended Songs by Track:
# Artist: drake
# Genre: hip-hop
# Popularity: 86
# Track: jimmy cooks (feat. 21 savage)
# URL: https://open.spotify.com/track/3F5CgOj3wFlRv51JsHbxhe
#
#
# Artist: drake
# Genre: hip-hop
# Popularity: 84
# Track: one dance
# URL: https://open.spotify.com/track/1zi7xx7UVEFkmKfv06H8x0
#
#
# Artist: drake
# Genre: hip-hop
# Popularity: 83
# Track: god's plan
# URL: https://open.spotify.com/track/6DCZcSspjsKoFjzjrWoCdn
#
#
# Artist: drake
# Genre: hip-hop
# Popularity: 82
# Track: spin bout u
# URL: https://open.spotify.com/track/2ZL7WZcjuYKi1KUDtp4kCC
#
#
# Artist: drake
# Genre: hip-hop
# Popularity: 81
# Track: pussy & millions (feat. travis scott)
# URL: https://open.spotify.com/track/2KLwPaRDOB87XOYAT2fgxh

# %%
recommendation_engine_wow = SongRecommendation_lovely(filtered_df)

# Take user input for the song name and artist name
user_input_songs = input("Enter the song name: ")
user_input_artist_name = input("Enter the artist name: ")

# Clean the user inputs
clean_input_for_songs = input_cleaning(user_input_songs)

clean_input_for_artist = input_cleaning(user_input_artist_name)

recommended_similar_songs_holy = recommendation_engine_wow.recommend_similar_songs(clean_input_for_artist, clean_input_for_songs)

if recommended_similar_songs_holy.empty.empty:
    print("No recommended songs found for the specified artist or song.")
else:
    if not recommended_similar_songs_holy.empty:
        print("Recommended Songs by Track:")
        for index, song in recommended_similar_songs_holy.iterrows():
            print(f"Artist: {song['artist_name']}")
            print(f"Genre: {song['genre']}")
            print(f"Popularity: {song['popularity']}")
            print(f"Track: {song['track_name']}")
            print(f"URL: {song['info_url']}")
            print("\n")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# f:\mlops2\notebook\visualization.ipynb Cell 69 line 1
#      <a href='vscode-notebook-cell:/f%3A/mlops2/notebook/visualization.ipynb#Y125sZmlsZQ%3D%3D?line=9'>10</a> clean_input_for_artist = input_cleaning(user_input_artist_name)
#      <a href='vscode-notebook-cell:/f%3A/mlops2/notebook/visualization.ipynb#Y125sZmlsZQ%3D%3D?line=11'>12</a> recommended_similar_songs_holy = recommendation_engine_wow.recommend_similar_songs(clean_input_for_artist, clean_input_for_songs)
# ---> <a href='vscode-notebook-cell:/f%3A/mlops2/notebook/visualization.ipynb#Y125sZmlsZQ%3D%3D?line=13'>14</a> if recommended_similar_songs_holy.empty.empty:
#      <a href='vscode-notebook-cell:/f%3A/mlops2/notebook/visualization.ipynb#Y125sZmlsZQ%3D%3D?line=14'>15</a>     print("No recommended songs found for the specified artist or song.")
# ...

# %%
filtered_df.columns
# Out:
# Index(['artist_name', 'track_name', 'popularity', 'year', 'genre', 'track_id',
#        'info_url'],
#       dtype='object')

# %%
filtered_df['year'].value_counts()
# Out:
# year
# 2022    37677
# 2021    34695
# 2020    33559
# 2019    33006
# 2018    31355
# 2017    29743
# 2015    23099
# 2014    21621
# 2016    20697
# 2013    19552
# 2012    17988
# 2023    17094
# 2011    14757
# 2010    13431
# 2009    13269
# 2008    12273
# 2007    11998
# 2006    11408
# 2005    11294
# 2004    10033
# 2003     9873
# 2002     9119
# 2001     8557
# 2000     8427
# Name: count, dtype: int64

# %%
def finding_the_most_popular_artist(df, desired_year:int):
    try:
        
        if 'year' not in df.columns or 'popularity' not in df.columns:
            raise KeyError("The 'year' or 'popularity' columns do not exist in the DataFrame.")

        songs_in_desired_year = df[df['year'] == desired_year]

        # Check if there are any songs for the desired year
        if songs_in_desired_year.empty:
            print(f"No songs found for the year {desired_year}.")
            return None

        sorted_songs = songs_in_desired_year.sort_values(by='popularity', ascending=False)
        top_n_songs = sorted_songs.head(10)
        top_n_songs_songs = top_n_songs[['artist_name','track_name','year','popularity']]
        return top_n_songs_songs
    except KeyError as e:
        print(f"An error occurred while getting the artist: {str(e)}")
        return None
    except ValueError as e:
        print(f"An error occurred while sorting the songs: {str(e)}")
        return None

# %%
top_n_songs = finding_the_most_popular_artist(filtered_df,2017)
top_n_songs
# Out:
#                    artist_name                                 track_name  \
# 129889  white noise baby sleep  clean white noise - loopable with no fade
# 125373                 ruth b.                                 dandelions
# 125376              ed sheeran                                    perfect
# 127319         imagine dragons                                   believer
# 114137            xxxtentacion                                    revenge
# 109127            shawn mendes            there's nothing holdin' me back
# 125385              ed sheeran                               shape of you
# 125372            taylor swift                             don’t blame me
# 120673          kendrick lamar                                    humble.
# 127320         imagine dragons                                    thunder
#
#         year  popularity
# 129889  2017          87
# 125373  2017          87
# 125376  2017          87
# 127319  2017          86
# ...

# %%
yearly_plotting = top_n_songs['year'].unique()
yearly_plotting
# Out:
# array([2017], dtype=int64)

# %%
def plotting_most_popular_artist(df, yearly_plotting):
    colors = ['royalblue', 'forestgreen', 'firebrick', 'gold', 'mediumorchid', 'dodgerblue', 'limegreen', 'tomato', 'indigo', 'orange']

    plt.figure(figsize=(10, 6))
    plt.barh(df['artist_name'], df['popularity'], color=colors)
    plt.xlabel('Artist Name', fontsize=12)
    plt.ylabel('Popularity', fontsize=12)
    plt.title(f'Top Ten Artists by Popularity in the year: {yearly_plotting}', fontsize=14, fontweight='bold')
    plt.gca().invert_yaxis()
    plt.grid(True, axis='y', linestyle='--', alpha=0.6)

    # Remove background color
    plt.gca().set_facecolor('none')

    # Add data labels
    for i, v in enumerate(df['popularity']):
        plt.text(i, v + 1, str(v), color='black', ha='center', fontsize=10, fontweight='bold')

    plt.xticks(rotation=45, ha='right', fontsize=10)
    plt.yticks(fontsize=10)

    plt.tight_layout()
    plt.show()

# %%
filtered_df['year'].unique()
# Out:
# array([2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022,
#        2023, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009,
#        2010, 2011], dtype=int64)

# %%
# List of target artists to analyze
target_artists = ['Taylor Swift', 'Adele','Lana Del Rey']

# Create a line plot to show the popularity growth for each artist over time
plt.figure(figsize=(10, 6))

for artist in target_artists:
    # Filter the DataFrame to select data for the specific artist
    artist_data = filtered_df[filtered_df['artist_name'] == artist]

    # Group the data by 'year' and calculate the mean popularity for each year
    popularity_growth = artist_data.groupby('year')['popularity'].mean()

    # Plot the popularity growth for the artist
    plt.plot(popularity_growth.index, popularity_growth.values, marker='o', linestyle='-', label=artist)

plt.title('Popularity Growth for Artists Over Time')
plt.xlabel('Year')
plt.ylabel('Mean Popularity')
plt.legend()
plt.grid(True)
plt.show()

# %%
def comparing_the_yearly_growth(df, target_artists):
    # Create a line plot to show the popularity growth for each artist over time
    plt.figure(figsize=(8, 4))

    if isinstance(target_artists, str):
        # If target_artists is a single string, convert it to a list for consistency
        target_artists = [target_artists]

    for artist in target_artists:
        # Convert the artist name to lowercase for case-insensitive matching
        artist = artist.lower()

        # Filter the DataFrame to select data for the specific artist
        artist_data = df[df['artist_name'].str.lower() == artist]

        # Determine the columns dynamically
        columns = {
            'artist_name': None,
            'year': None,
            'popularity': None
        }

        for column in df.columns:
            for key in columns:
                if key in column.lower():
                    columns[key] = column

        if all(columns.values()):
            # Group the data by 'year' and calculate the mean popularity for each year
            popularity_growth = artist_data.groupby(columns['year'])[columns['popularity']].mean()

            # Plot the popularity growth for the artist
            plt.plot(popularity_growth.index, popularity_growth.values, marker='o', linestyle='-', label=artist)

    plt.title(f'Popularity Growth for {", ".join(target_artists)} Over Time')
    plt.xlabel('Year')
    plt.ylabel('Mean Popularity')
    plt.legend()
    plt.grid(True)

# %%
def create_pie_chart(df, target_artist):
    # Convert the target_artist name to lowercase for case-insensitive matching
    target_artist = target_artist.lower()

    # Filter the DataFrame to select data for the specific artist
    artist_data = df[df['artist_name'].str.lower() == target_artist]

    if artist_data.empty:
        return None  # Return None if the artist is not found in the DataFrame

    # Determine the columns dynamically
    columns = {
        'artist_name': None,
        'genre': None,
        'popularity': None
    }

    for column in df.columns:
        for key in columns:
            if key in column.lower():
                columns[key] = column

    if all(columns.values()):
        # Group the data by 'genre' and calculate the sum of popularity for each genre
        genre_popularity = artist_data.groupby(columns['genre'])[columns['popularity']].sum()

        # Create a pie chart to visualize genre popularity for the artist
        plt.figure(figsize=(8, 8))
        
        # Determine the number of genres for explode parameter
        num_genres = len(genre_popularity)
        explode = tuple(0.1 for _ in range(num_genres))  # Explode slices for emphasis
        
        colors = ['#ff9999', '#66b3ff', '#99ff99', '#ffcc99', '#c2c2f0', '#ffb3e6', '#c2f0c2', '#ffccff', '#ffff99', '#b3b3cc']

        
        plt.pie(
            genre_popularity,
            labels=genre_popularity.index,
            autopct='%1.1f%%',
            startangle=140,
            colors=colors,
            explode=explode,
            shadow=True
        )
        plt.title(f'Genre Popularity Distribution for {target_artist}', fontsize=16)
        plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle

        return plt  # Return the Matplotlib figure for the pie chart

    return None

# %%
artist_pie = ['sza','drake','taylor swift']
for i in artist_pie:
    pie_chart = create_pie_chart(df,i )
    if pie_chart:
        plt.show()

# %%
filtered_df.columns
# Out:
# Index(['artist_name', 'track_name', 'popularity', 'year', 'genre', 'track_id',
#        'info_url'],
#       dtype='object')

# %%
df['year'].unique()
# Out:
# array([2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022,
#        2023, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009,
#        2010, 2011], dtype=int64)

# %%
plt.figure(figsize=(15, 6))
sns.boxplot(x='genre', y='popularity', data=filtered_df)
plt.xticks(rotation=90)
plt.xlabel('Genre')
plt.ylabel('Popularity')
plt.title('Comparison of Popularity by Genre')
plt.show()

# %%
def create_genre_popularity_boxplot(data, x_col, y_col):
    """
    Create a box plot to compare popularity by genre.

    Parameters:
        data (pd.DataFrame): The DataFrame containing the data.
        x_col (str): The column for the x-axis (e.g., 'genre').
        y_col (str): The column for the y-axis (e.g., 'popularity').
    """
    plt.figure(figsize=(, 6))
    sns.boxplot(x=x_col, y=y_col, data=data)
    plt.xticks(rotation=90)
    plt.xlabel(x_col.capitalize())
    plt.ylabel(y_col.capitalize())
    plt.title(f'Comparison of {y_col.capitalize()} by {x_col.capitalize()}')
    plt.show()

# %%
create_genre_popularity_boxplot(filtered_df,'genre','popularity')
